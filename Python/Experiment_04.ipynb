# %% [markdown]
# # Experiment No. 4

# %% [markdown]
# ## Lists in Python
#
#
# List
# - It consists of a group of elements.
# - A single list may contain DataTypes like Integers, Strings, as well as Objects.
# - They are dynamic, mutable & ordered.
# - It is represented by square brackets.
#
# Operation on List used
# 1. append(x) - To add value x at end of the list
# 2. sort() -To sort items in a list in ascending order

# %% [markdown]
# Q1. Write a menu driven program to demonstrate use of list in python
# 1. Put even and odd elements in two different list
# 2. Merge and sort two list
# 3. Update the first element with a value X
# 4. Print middle element of list

# %%
n=int(input('Enter Number Of Elements in List'))
lst=[]
for i in range(0,n,1):
    ele=int(input('Enter element: '))
    lst.append(ele)
    
print("Output:-")
choice = 1
while choice != 0:
    print("\n1.Put even and odd elemnts in two different list")
    print("2.Merge and sort two list")
    print("3.Update the first element with a value X")
    print("4.Print middle element of list")
    print("5.Exit")
    choice = int(input("Enter choice: "))
    if choice == 1:
        even = []
        odd = []
        for j in lst:
            if j % 2 == 0:
                even.append(j)
            else:
                odd.append(j)
        print("The even list: ", even)
        print("The odd list: ", odd)
    elif (choice == 2):
        d = []
        new = []
        n1 = int(input("Enter number of elements: "))
        for i in range(1, n1 + 1):
            f = int(input("Enter element: "))
            d.append(f)
        new = lst + d
        new.sort()
        print('Sorted list is: ', new)
    elif choice==3:
        h=[]      
        n2=int(input("Enter number of elements: "))      
        for i in range(1,n2+1):
            k=int(input("Enter element: "))
            h.append(k)      
        print("original list ",h)      
        elmnt=int(input("Enter the Element which is to be added"))      
        h[0]=elmnt      
        print("The updated list ",h)  
    elif choice==4:
        y=[]      
        n3=int(input("Enter number of elements:"))      
        for i in range(1,n3+1):
            x=int(input("Enter element:"))
            y.append(x)
        print("list is ",y)     
        print("mid value is ",y[int(len(y)/2)])  
    elif choice==5:
        break  
    else:     
        print("Please enter a valid choice")
# Out:
# Enter Number Of Elements in List5
# Enter element: 8
# Enter element: 7
# Enter element: 4
# Enter element: 9
# Enter element: 2
# Output:-
#
# 1.Put even and odd elemnts in two different list
# 2.Merge and sort two list
# 3.Update the first element with a value X
# 4.Print middle element of list
# 5.Exit
# Enter choice: 1
# The even list:  [8, 4, 2]
# The odd list:  [7, 9]
#
# 1.Put even and odd elemnts in two different list
# 2.Merge and sort two list
# 3.Update the first element with a value X
# 4.Print middle element of list
# 5.Exit
# Enter choice: 2
# Enter number of elements: 4
# Enter element: 1
# Enter element: 5
# Enter element: 4
# Enter element: 6
# Sorted list is:  [1, 2, 4, 4, 5, 6, 7, 8, 9]
#
# 1.Put even and odd elemnts in two different list
# 2.Merge and sort two list
# 3.Update the first element with a value X
# 4.Print middle element of list
# 5.Exit
# Enter choice: 3
# Enter number of elements: 5
# Enter element: 4
# Enter element: 5
# Enter element: 8
# Enter element: 7
# Enter element: 9
# original list  [4, 5, 8, 7, 9]
# Enter the Element which is to be added6
# The updated list  [6, 5, 8, 7, 9]
#
# 1.Put even and odd elemnts in two different list
# 2.Merge and sort two list
# 3.Update the first element with a value X
# 4.Print middle element of list
# 5.Exit
# Enter choice: 4
# Enter number of elements:6
# Enter element:9
# Enter element:8
# Enter element:7
# Enter element:5
# Enter element:4
# Enter element:6
# list is  [9, 8, 7, 5, 4, 6]
# mid value is  5
#
# 1.Put even and odd elemnts in two different list
# 2.Merge and sort two list
# 3.Update the first element with a value X
# 4.Print middle element of list
# 5.Exit
# Enter choice: 5

# %% [markdown]
# ## Tuples in Python
#
# A tuple in Python is similar to a list.
#
# The difference between the two is that we cannot change the elements of a tuple once it is assigned whereas we can change the elements of a list.
#
# A tuple is created by placing all the items (elements) inside parentheses (), separated by commas. The parentheses are optional, however, it is a good practice to use them.
#
# In this question we used list to take in the input from user and later convert it into tuple
#
# Program
#
# Q2. Write a menu driven program to demonstrate use of tuple in python
# 1. Add and show details i.e roll no, name and marks of three subjects of N students in a list of tuple
# 2. Display details of a student whose name is X

# %%
students=[]
ch=0 
while(ch!=3):
    print("MENU\n")     
    print("1. Add new student\n2. Display student info\n3. Exit\nEnter your choice:")     
    ch=int(input())     
    if (ch==1):         
        list=[]         
        rollno = input("Enter student roll no:")         
        list.append(rollno)         
        name = input("Enter student name:")         
        list.append(name)         
        marks1= input("Enter student physics marks:")         
        list.append(marks1)         
        marks2= input("Enter student chemistry marks:")         
        list.append(marks2)         
        marks3= input("Enter student maths marks:")         
        list.append(marks3)         
        students.append(list)     
    elif (ch==2):         
        flag=0         
        target=input("Enter name of student whose details are to be displayed:")         
        for index, tuple in enumerate(students):
            name=tuple[1]             
            if(name==target):
                print(students[index])                 
                flag=1                 
                break         
        if (flag==0):
            print("Student does not exist in the list")     
    elif (ch==3):         
        print("Thank you for using the system!")
# Out:
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 1
# Enter student roll no:112
# Enter student name:Tushar
# Enter student physics marks:12
# Enter student chemistry marks:24
# Enter student maths marks:36
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 1
# Enter student roll no:113
# Enter student name:Vivek
# Enter student physics marks:55
# Enter student chemistry marks:68
# Enter student maths marks:75
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 1
# Enter student roll no:114
# Enter student name:Parth
# Enter student physics marks:89
# Enter student chemistry marks:78
# Enter student maths marks:54
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 2
# Enter name of student whose details are to be displayed:Tushar
# ['112', 'Tushar', '12', '24', '36']
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 2
# Enter name of student whose details are to be displayed:Vivek
# ['113', 'Vivek', '55', '68', '75']
# MENU
#
# 1. Add new student
# 2. Display student info
# 3. Exit
# Enter your choice:
# 3
# Thank you for using the system!

# %% [markdown]
# ## Sets in Python
#
# Sets
#
# - Sets are unordered
# - Set elements are unique.
# - Duplicate elements are not allowed
# - A set itself is mutable i.e. you can add or remove elements from set
# - Elements contained in the sets must be of immutable type. (strings, tuples, Numeric)
# - Sets can have different type of elements that is they can be heterogeneous in nature
#
# #### Set Methods
# 1. intersection()	Returns a set, that is the intersection of two other sets
# 2. union()	Return a set containing the union of sets
# 3. difference()	Returns a set containing the difference between two or more sets
# 4. symmetric_difference()	Returns a set with the symmetric differences of two sets
#
# Program
#
# Q3. Write a menu driven program to demonstrate use of set in python
# 1. Read two sets A and B from user and display set  A and B
# 2. Perform intersection A ∩ B of two sets A and B
# 3. Perform union A UB of two sets A and B
# 4. Perform set difference  A -B of two sets A and B
# 5. Perform symmetric difference  A ^ B of two sets A and B

# %%
print("Output:-")
A={}
B={}
A=set(input("Enter the set A:")) 
print(A)
B=set(input("Enter the set B:")) 
print(B) 
choice=1 
while choice!=0:
    print("1.Perform intersection A ∩ B of two sets A and B")  
    print("2.Perform union A ∩ B of two sets A and B")  
    print("3.Perform set difference A U B of two sets A and B")  
    print("4.Perform symmetric difference A ^ B of two sets A and B")  
    print("5.Exit")  
    choice=int(input("Enter choice: "))  
    if choice==1:   
        print(A & B)   
        print()  
    elif choice==2:   
        print(A | B)   
        print()  
    elif choice==3:   
        print(A - B)   
        print()  
    elif choice==4:   
        print(A ^ B)   
        print()  
    elif choice==5:
        break  
    else:
        print("Enter a valid choice. ")   
        print()
# Out:
# Output:-
# Enter the set A:8 7 9 4 1 2
# {'1', '9', '4', ' ', '8', '7', '2'}
# Enter the set B:5 6 6 7 8 7
# {'6', ' ', '8', '7', '5'}
# 1.Perform intersection A ∩ B of two sets A and B
# 2.Perform union A ∩ B of two sets A and B
# 3.Perform set difference A U B of two sets A and B
# 4.Perform symmetric difference A ^ B of two sets A and B
# 5.Exit
# Enter choice: 1
# {'7', ' ', '8'}
#
# 1.Perform intersection A ∩ B of two sets A and B
# 2.Perform union A ∩ B of two sets A and B
# 3.Perform set difference A U B of two sets A and B
# 4.Perform symmetric difference A ^ B of two sets A and B
# 5.Exit
# Enter choice: 2
# {'6', '1', '9', '4', ' ', '5', '8', '7', '2'}
#
# 1.Perform intersection A ∩ B of two sets A and B
# 2.Perform union A ∩ B of two sets A and B
# 3.Perform set difference A U B of two sets A and B
# 4.Perform symmetric difference A ^ B of two sets A and B
# 5.Exit
# Enter choice: 3
# {'4', '1', '9', '2'}
#
# 1.Perform intersection A ∩ B of two sets A and B
# 2.Perform union A ∩ B of two sets A and B
# 3.Perform set difference A U B of two sets A and B
# 4.Perform symmetric difference A ^ B of two sets A and B
# 5.Exit
# Enter choice: 4
# {'6', '1', '9', '4', '5', '2'}
#
# 1.Perform intersection A ∩ B of two sets A and B
# 2.Perform union A ∩ B of two sets A and B
# 3.Perform set difference A U B of two sets A and B
# 4.Perform symmetric difference A ^ B of two sets A and B
# 5.Exit
# Enter choice: 5

# %% [markdown]
# ## Dictionary in Python
#
# - A dictionary represents a group of elements arranged in the form of key-value pairs.
# - In the dictionary, the first element is considered as 'key' and immediate next element is taken as its 'value'.
# - The key and values are separated by colon ( : )
# - All the key-value pairs in a dictionary are inserted in curly braces
#
# Methods Used
#
# - sorted( ) function can be used to sort the dictionary.
# - By default, the elements are sorted in ascending order.
# - The format of sorted function is
# - sorted(elements, key = <function>)
# - Elements of the dictionary can be accessed using method d.items()
# - key can be assigned with lambda function which will determine whether data to be sorted using Keys or Values.
# - Following function will consider keys for sorting the elements
#     key = lambda t : t[0]
#
# Program
#
# Q4. Write a program to demonstrate use of dictionary in python
# 1. Read a dictionary from the user and display.
# 2. To sort a dictionary by key
# 3. Concatenate two Python dictionaries into a new one

# %%
print("Output:-") 
a={} 
b={} 
n=int(input("Enter the no of elements for a ")) 
for i in range(n):
    k=input("Enter the key ")  
    v=input("Enter the value ")
    a.update({k:v}) 
print() 
print("The dictionary a is: ",a) 
print() 
n1=int(input("Enter the no of elements for b ")) 
for i in range(n1):
    t=input("Enter the key ")  
    w=input("Enter the value ")
    b.update({t:w}) 
print() 
print("The dictionary b is:",b) 
print() 
print("The sorted dictionary a according to the key is ", sorted(a.items())) 
print() 
print("The sorted dictionary b according to the key is ", sorted(b.items())) 
print()
a.update(b)
print("The concatenated dictionary is ",a)
# Out:
# Output:-
# Enter the no of elements for a 3
# Enter the key 112
# Enter the value Tushar
# Enter the key 113
# Enter the value Vivek
# Enter the key 114
# Enter the value Aakash
#
# The dictionary a is:  {'112': 'Tushar', '113': 'Vivek', '114': 'Aakash'}
#
# Enter the no of elements for b 2
# Enter the key 115
# Enter the value Rohit
# Enter the key 116
# Enter the value Chinmay
#
# The dictionary b is: {'115': 'Rohit', '116': 'Chinmay'}
#
# The sorted dictionary a according to the key is  [('112', 'Tushar'), ('113', 'Vivek'), ('114', 'Aakash')]
#
# The sorted dictionary b according to the key is  [('115', 'Rohit'), ('116', 'Chinmay')]
#
# The concatenated dictionary is  {'112': 'Tushar', '113': 'Vivek', '114': 'Aakash', '115': 'Rohit', '116': 'Chinmay'}
